# %%
import pubchempy as pcp
import pandas as pd
import py3Dmol

# %%
#CIDと名前を取ってくる
aa = pcp.get_compounds('alanine', 'name')
for i in aa:
    print('CID: {}\tName: {}'.format(i.cid, i.iupac_name))
# Out:
# CID: 602	Name: 2-aminopropanoic acid
# CID: 5950	Name: (2S)-2-aminopropanoic acid
# CID: 71080	Name: (2R)-2-aminopropanoic acid

# %%
#3次元情報の取得
l_ala_3d = pcp.get_compounds(5950, 'cid', record_type='3d')
l_ala_3d = l_ala_3d[0]
l_ala_3d.mmff94_energy_3d, l_ala_3d.volume_3d
# Out:
# (1.5212, 68.8)

# %%
#化合物名、分子式、分子量、XlogP、tPSA、構造式を抽出
properties = ['IUPACName', 'MolecularFormula', 'MolecularWeight', 'XLogP', 'TPSA', 'CanonicalSMILES']
a = pcp.get_properties(properties, 'alanine', 'name')
print(a)
# Out:
# [{'CID': 602, 'MolecularFormula': 'C3H7NO2', 'MolecularWeight': 89.09, 'CanonicalSMILES': 'CC(C(=O)O)N', 'IUPACName': '2-aminopropanoic acid', 'XLogP': -3, 'TPSA': 63.3}, {'CID': 5950, 'MolecularFormula': 'C3H7NO2', 'MolecularWeight': 89.09, 'CanonicalSMILES': 'CC(C(=O)O)N', 'IUPACName': '(2S)-2-aminopropanoic acid', 'XLogP': -3, 'TPSA': 63.3}, {'CID': 71080, 'MolecularFormula': 'C3H7NO2', 'MolecularWeight': 89.09, 'CanonicalSMILES': 'CC(C(=O)O)N', 'IUPACName': '(2R)-2-aminopropanoic acid', 'XLogP': -3, 'TPSA': 63.3}]

# %%
#pandas表示で化合物情報を取得
a = pcp.get_properties(properties, 'alanine', 'name', as_dataframe=True)
a
# Out:
#       CanonicalSMILES                   IUPACName MolecularFormula  \
# CID
# 602       CC(C(=O)O)N       2-aminopropanoic acid          C3H7NO2
# 5950      CC(C(=O)O)N  (2S)-2-aminopropanoic acid          C3H7NO2
# 71080     CC(C(=O)O)N  (2R)-2-aminopropanoic acid          C3H7NO2
#
#        MolecularWeight  TPSA  XLogP
# CID
# 602              89.09  63.3     -3
# 5950             89.09  63.3     -3
# 71080            89.09  63.3     -3

# %%
# Wikipediaからテーブルを取得して整形
dfs = pd.read_html('https://en.wikipedia.org/wiki/Amino_acid')
df = dfs[2]
df
names = df[1]

# %%
names = names.drop(names.index[[0,1]])

# %%
# 得られたリストを使ってPubChemからプロパティを取得し，データフレーム型に加工
def Boc_AA_OH(name_list):
    properties = ['iupacname', 'molecularformula', 'molecularweight', 'xlogp', 'tpsa', 'canonicalsmiles']
    return_list = []
    for n in name_list:
        AA = 'Boc-' + n + '-OH'
        x = pcp.get_properties(properties, AA, 'name')
        if len(x) == 1:
            return_list.append(x[0])
        else:
            return_list.append('NA')
            print('{} was not retrived properly.')
    return return_list
 
y = Boc_AA_OH(names)
aa_df = pd.DataFrame(y)
aa_df.index = aa_df['CID']
aa_df = aa_df.drop('CID', axis=1)

# %%
aa_df
# Out:
#                                     CanonicalSMILES  \
# CID
# 85082                     CC(C(=O)O)NC(=O)OC(C)(C)C
# 114667           CC(C)(C)OC(=O)NC(CCCN=C(N)N)C(=O)O
# 82035               CC(C)(C)OC(=O)NC(CC(=O)N)C(=O)O
# 99718               CC(C)(C)OC(=O)NC(CC(=O)O)C(=O)O
# 152319                   CC(C)(C)OC(=O)NC(CS)C(=O)O
# 83687              CC(C)(C)OC(=O)NC(CCC(=O)N)C(=O)O
# 2724758            CC(C)(C)OC(=O)NC(CCC(=O)O)C(=O)O
# 78288                        CC(C)(C)OC(=O)NCC(=O)O
# 87308            CC(C)(C)OC(=O)NC(CC1=CN=CN1)C(=O)O
# 2724762              CCC(C)C(C(=O)O)NC(=O)OC(C)(C)C
# 83170                CC(C)CC(C(=O)O)NC(=O)OC(C)(C)C
# 2733284               CC(C)(C)OC(=O)NC(CCCCN)C(=O)O
# 89857                  CC(C)(C)OC(=O)NC(CCSC)C(=O)O
# 77857          CC(C)(C)OC(=O)NC(CC1=CC=CC=C1)C(=O)O
# 85083                   CC(C)(C)OC(=O)N1CCCC1C(=O)O
# 98766                    CC(C)(C)OC(=O)NC(CO)C(=O)O
# 2724766               CC(C(C(=O)O)NC(=O)OC(C)(C)C)O
# 83169    CC(C)(C)OC(=O)NC(CC1=CNC2=CC=CC=C21)C(=O)O
# 117439      CC(C)(C)OC(=O)NC(CC1=CC=C(C=C1)O)C(=O)O
# 83693                 CC(C)C(C(=O)O)NC(=O)OC(C)(C)C
#
#                                                  IUPACName MolecularFormula  \
# CID
# 85082    (2S)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...         C8H15NO4
# 114667   (2S)-5-(diaminomethylideneamino)-2-[(2-methylp...       C11H22N4O4
# 82035    (2S)-4-amino-2-[(2-methylpropan-2-yl)oxycarbon...        C9H16N2O5
# 99718    (2S)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...         C9H15NO6
# 152319   (2R)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...        C8H15NO4S
# 83687    (2S)-5-amino-2-[(2-methylpropan-2-yl)oxycarbon...       C10H18N2O5
# 2724758  (2S)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...        C10H17NO6
# 78288    2-[(2-methylpropan-2-yl)oxycarbonylamino]aceti...         C7H13NO4
# 87308    (2S)-3-(1H-imidazol-5-yl)-2-[(2-methylpropan-2...       C11H17N3O4
# 2724762  (2S,3S)-3-methyl-2-[(2-methylpropan-2-yl)oxyca...        C11H21NO4
# 83170    (2S)-4-methyl-2-[(2-methylpropan-2-yl)oxycarbo...        C11H21NO4
# 2733284  (2S)-6-amino-2-[(2-methylpropan-2-yl)oxycarbon...       C11H22N2O4
# 89857    (2S)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...       C10H19NO4S
# 77857    (2S)-2-[(2-methylpropan-2-yl)oxycarbonylamino]...        C14H19NO4
# 85083    (2S)-1-[(2-methylpropan-2-yl)oxycarbonyl]pyrro...        C10H17NO4
# 98766    (2S)-3-hydroxy-2-[(2-methylpropan-2-yl)oxycarb...         C8H15NO5
# 2724766  (2S,3R)-3-hydroxy-2-[(2-methylpropan-2-yl)oxyc...         C9H17NO5
# 83169    (2S)-3-(1H-indol-3-yl)-2-[(2-methylpropan-2-yl...       C16H20N2O4
# 117439   (2S)-3-(4-hydroxyphenyl)-2-[(2-methylpropan-2-...        C14H19NO5
# 83693    (2S)-3-methyl-2-[(2-methylpropan-2-yl)oxycarbo...        C10H19NO4
#
#          MolecularWeight   TPSA  XLogP
# CID
# 85082             189.21   75.6    0.9
# 114667            274.32  140.0   -0.3
# 82035             232.23  119.0   -0.6
# 99718             233.22  113.0    0.1
# 152319            221.28   76.6    0.8
# 83687             246.26  119.0   -0.2
# 2724758           247.24  113.0    0.4
# 78288             175.18   75.6    0.5
# 87308             255.27  104.0    0.7
# 2724762           231.29   75.6    1.6
# 83170             231.29   75.6    2.2
# 2733284           246.30  102.0   -1.6
# 89857             249.33  101.0    1.6
# 77857             265.30   75.6    2.2
# 85083             215.25   66.8    1.5
# 98766             205.21   95.9   -0.1
# 2724766           219.23   95.9    0.3
# 83169             304.34   91.4    2.0
# 117439            281.30   95.9    1.5
# 83693             217.26   75.6    1.5

# %%
#アラニンの立体構造描写
view = py3Dmol.view(width=680, height=250, query='cid:5950', viewergrid=(1,3), linked=False)
view.setStyle({'line': {'linewidth': 5}}, viewer=(0,0))
view.setStyle({'stick': {}}, viewer=(0,1))
view.setStyle({'sphere': {}}, viewer=(0,2))
view.setBackgroundColor('#ebf4fb', viewer=(0,0))
view.setBackgroundColor('#f9f4fb', viewer=(0,1))
view.setBackgroundColor('#e1e1e1', viewer=(0,2))
view.show()
view.png()
# Out:
# <div id="3dmolviewer_16056865672006578"  style="position: relative; width: 680px; height: 250px">
#         <p id="3dmolwarning_16056865672006578" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16056865672006578 = null;
# var warn = document.getElementById("3dmolwarning_16056865672006578");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_16056865672006578 = null;
# viewergrid_16056865672006578 = $3Dmol.createViewerGrid($("#3dmolviewer_16056865672006578"),{rows: 1, cols: 3, control_all: false},{backgroundColor:"white"});
# viewer_16056865672006578 = viewergrid_16056865672006578[0][0];
# $3Dmol.download("cid:5950", viewergrid_16056865672006578[0][0], {}, function() {
# $3Dmol.download("cid:5950", viewergrid_16056865672006578[0][1], {}, function() {
# $3Dmol.download("cid:5950", viewergrid_16056865672006578[0][2], {}, function() {
# 	viewergrid_16056865672006578[0][0].setStyle({"line": {"linewidth": 5}});
# 	viewergrid_16056865672006578[0][1].setStyle({"stick": {}});
# 	viewergrid_16056865672006578[0][2].setStyle({"sphere": {}});
# 	viewergrid_16056865672006578[0][0].setBackgroundColor("#ebf4fb");
# 	viewergrid_16056865672006578[0][1].setBackgroundColor("#f9f4fb");
# 	viewergrid_16056865672006578[0][2].setBackgroundColor("#e1e1e1");
# viewergrid_16056865672006578[0][2].zoomTo(); viewergrid_16056865672006578[0][2].render();
# viewergrid_16056865672006578[0][1].zoomTo(); viewergrid_16056865672006578[0][1].render();
# viewergrid_16056865672006578[0][0].zoomTo(); viewergrid_16056865672006578[0][0].render();
# })
# })
# })
# });
# </script>
# <img id="img_16056865672006578">
#             <script>
#             var png = viewer_16056865672006578.pngURI()
#             $('#img_16056865672006578').attr('src', png)
#             </script>

# %%
#タンパク質1zniの立体構造描写
view = py3Dmol.view(width=680, height=480, query='pdb:1zni', viewergrid=(2,2), linked=False)
view.setStyle({'cartoon': {'color': 'spectrum'}}, viewer=(0,0))
view.setStyle({'chain': 'A'}, {'cartoon': {'color': '#4aa6ff', 'style': 'oval'}}, viewer=(0,1))
view.setStyle({'chain': 'B'}, {'cartoon': {'color': '#f65fab', 'style': 'edged'}}, viewer=(0,1))
view.setStyle({'chain': 'C'}, {'stick': {}}, viewer=(0,1))
view.setStyle({'chain': 'D'}, {'stick': {'color': 'black'}}, viewer=(0,1))
view.setStyle({'cartoon': {'color': 'spectrum'}}, viewer=(1,0))
view.setStyle({'elem': 'Zn'}, {'sphere': {'scale': 2.0}}, viewer=(1,0))
view.setStyle({'sphere': {'color': '#CCD1D1'}}, viewer=(1,1))
view.addSurface(py3Dmol.VDW, {'opacity': 0.5}, viewer=(0,0))
view.addSurface(py3Dmol.SES, {'opacity': 0.6, 'color': '#FADBD8'}, viewer=(0,1))
view.addSurface(py3Dmol.SAS, {'opacity': 0.6, 'color': '#FDEBD0'}, viewer=(1,0))
view.setBackgroundColor('#e1e1e1')
view.show()
# Out:
# <div id="3dmolviewer_16056866573468795"  style="position: relative; width: 680px; height: 480px">
#         <p id="3dmolwarning_16056866573468795" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#       resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://3dmol.org/build/3Dmol.js');
# }
#
# var viewer_16056866573468795 = null;
# var warn = document.getElementById("3dmolwarning_16056866573468795");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# var viewergrid_16056866573468795 = null;
# viewergrid_16056866573468795 = $3Dmol.createViewerGrid($("#3dmolviewer_16056866573468795"),{rows: 2, cols: 2, control_all: false},{backgroundColor:"white"});
# viewer_16056866573468795 = viewergrid_16056866573468795[0][0];
# $3Dmol.download("pdb:1zni", viewergrid_16056866573468795[0][0], {}, function() {
# $3Dmol.download("pdb:1zni", viewergrid_16056866573468795[0][1], {}, function() {
# $3Dmol.download("pdb:1zni", viewergrid_16056866573468795[1][0], {}, function() {
# $3Dmol.download("pdb:1zni", viewergrid_16056866573468795[1][1], {}, function() {
# 	viewergrid_16056866573468795[0][0].setStyle({"cartoon": {"color": "spectrum"}});
# 	viewergrid_16056866573468795[0][1].setStyle({"chain": "A"},{"cartoon": {"color": "#4aa6ff", "style": "oval"}});
# 	viewergrid_16056866573468795[0][1].setStyle({"chain": "B"},{"cartoon": {"color": "#f65fab", "style": "edged"}});
# 	viewergrid_16056866573468795[0][1].setStyle({"chain": "C"},{"stick": {}});
# 	viewergrid_16056866573468795[0][1].setStyle({"chain": "D"},{"stick": {"color": "black"}});
# 	viewergrid_16056866573468795[1][0].setStyle({"cartoon": {"color": "spectrum"}});
# 	viewergrid_16056866573468795[1][0].setStyle({"elem": "Zn"},{"sphere": {"scale": 2.0}});
# 	viewergrid_16056866573468795[1][1].setStyle({"sphere": {"color": "#CCD1D1"}});
# 	viewergrid_16056866573468795[0][0].addSurface(1,{"opacity": 0.5});
# 	viewergrid_16056866573468795[0][1].addSurface(4,{"opacity": 0.6, "color": "#FADBD8"});
# 	viewergrid_16056866573468795[1][0].addSurface(3,{"opacity": 0.6, "color": "#FDEBD0"});
# 	viewergrid_16056866573468795[0][0].setBackgroundColor("#e1e1e1");
# 	viewergrid_16056866573468795[0][1].setBackgroundColor("#e1e1e1");
# 	viewergrid_16056866573468795[1][0].setBackgroundColor("#e1e1e1");
# 	viewergrid_16056866573468795[1][1].setBackgroundColor("#e1e1e1");
# viewergrid_16056866573468795[1][1].zoomTo(); viewergrid_16056866573468795[1][1].render();
# viewergrid_16056866573468795[1][0].zoomTo(); viewergrid_16056866573468795[1][0].render();
# viewergrid_16056866573468795[0][1].zoomTo(); viewergrid_16056866573468795[0][1].render();
# viewergrid_16056866573468795[0][0].zoomTo(); viewergrid_16056866573468795[0][0].render();
# })
# })
# })
# })
# });
# </script>
