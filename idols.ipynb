# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:/Users/takah/imas/cindellera.csv', encoding="shift-jis")

# %%
df
# Out:
#       ID type       name   age birthday   星座 bloodtype  height  weight     B  \
# 0      1   Cu       相原雪乃  22.0    2月14日  水瓶座         A     160    51.0  92.0
# 1      2   Cu      赤西瑛梨華  16.0     7月7日   蟹座         O     154    55.0  92.0
# 2      3   Cu       浅野風香  16.0    2月11日  水瓶座         A     160    48.0  88.0
# 3      4   Cu       安部菜々  17.0    5月15日  牡牛座         O     146    40.0  84.0
# 4      5   Cu       有浦柑奈  19.0     3月6日   魚座         O     155    44.0  78.0
# 5      6   Cu        安斎都  16.0     1月6日  山羊座         B     156    41.0  78.0
# 6      7   Cu      五十嵐響子  15.0    8月10日  獅子座        AB     154    43.0  81.0
# 7      8   Cu       池袋晶葉  14.0    6月10日  双子座         B     148    39.0  75.0
# 8      9   Cu      一ノ瀬志希  18.0    5月30日  双子座         O     161    43.0  83.0
# 9     10   Cu       今井加奈  16.0     3月3日   魚座         O     153    41.0  81.0
# 10    11   Cu       井村雪菜  17.0    8月27日  乙女座        AB     163    48.0  85.0
# ...

# %%
df.describe()
# Out:
#                ID         age      height      weight           B           W  \
# count  195.000000  194.000000  195.000000  192.000000  191.000000  191.000000
# mean    98.000000   17.505155  156.210256   43.161458   80.905759   56.319372
# std     56.435804    4.154088    8.857515    4.943659    6.579995    2.566503
# min      1.000000    9.000000  127.000000   28.000000   60.000000   47.000000
# 25%     49.500000   15.000000  152.000000   41.000000   77.500000   55.000000
# 50%     98.000000   17.000000  157.000000   43.000000   81.000000   56.000000
# 75%    146.500000   19.000000  162.000000   46.000000   85.000000   58.000000
# max    195.000000   31.000000  182.000000   60.000000  105.000000   65.000000
#
#                 H
# count  191.000000
# mean    81.324607
# std      4.941699
# min     65.000000
# 25%     79.000000
# 50%     82.000000
# 75%     85.000000
# max     93.000000

# %%
df.median()
# Out:
# ID         98.0
# age        17.0
# height    157.0
# weight     43.0
# B          81.0
# W          56.0
# H          82.0
# dtype: float64

# %%
print(df.query('type == "Pa"'))
# Out:
#       ID type        name   age birthday   星座 bloodtype  height  weight  \
# 130  131   Pa         愛野渚  18.0     8月1日  獅子座         A     163    47.0
# 131  132   Pa        相葉夕美  18.0    4月15日  牡羊座         O     158    42.0
# 132  133   Pa       赤城みりあ  11.0    4月14日  牡羊座        AB     140    36.0
# 133  134   Pa  イヴ・サンタクロース  19.0   12月24日  山羊座         B     165    44.0
# 134  135   Pa        市原仁奈   9.0     2月8日  水瓶座         B     128    29.0
# 135  136   Pa        上田鈴帆  14.0   10月26日   蠍座         O     156    42.0
# 136  137   Pa       衛藤美紗希  22.0    3月18日   魚座         O     160    45.0
# 137  138   Pa       海老原菜帆  17.0     8月3日  獅子座         O     162    58.0
# 138  139   Pa         及川雫  16.0     6月3日  双子座         O     170    56.0
# 139  140   Pa         大槻唯  17.0     5月7日  牡牛座         B     155    42.0
# 140  141   Pa        片桐早苗  28.0     3月7日   魚座         O     152    47.0
# 141  142   Pa        北川真尋  17.0    2月17日  水瓶座         O     158    43.0
# ...

# %%
df[df['weight'].isnull()]
# Out:
#       ID type   name   age birthday   星座 bloodtype  height  weight     B  \
# 151  152   Pa    佐藤心  26.0    7月22日   蟹座        AB     166     NaN   NaN
# 186  187   Pa  夢見りあむ  19.0    9月12日  乙女座        AB     149     NaN   NaN
# 190  191   --  千川ちひろ   NaN   11月28日  射手座         A     154     NaN  82.0
#
#         W     H hand   place
# 151   NaN   NaN    右      長野
# 186   NaN   NaN    右  やさしい世界
# 190  58.0  84.0    右      東京

# %%
df2 = df.dropna()
df2
# Out:
#       ID type       name   age birthday   星座 bloodtype  height  weight     B  \
# 0      1   Cu       相原雪乃  22.0    2月14日  水瓶座         A     160    51.0  92.0
# 1      2   Cu      赤西瑛梨華  16.0     7月7日   蟹座         O     154    55.0  92.0
# 2      3   Cu       浅野風香  16.0    2月11日  水瓶座         A     160    48.0  88.0
# 3      4   Cu       安部菜々  17.0    5月15日  牡牛座         O     146    40.0  84.0
# 4      5   Cu       有浦柑奈  19.0     3月6日   魚座         O     155    44.0  78.0
# 5      6   Cu        安斎都  16.0     1月6日  山羊座         B     156    41.0  78.0
# 6      7   Cu      五十嵐響子  15.0    8月10日  獅子座        AB     154    43.0  81.0
# 7      8   Cu       池袋晶葉  14.0    6月10日  双子座         B     148    39.0  75.0
# 8      9   Cu      一ノ瀬志希  18.0    5月30日  双子座         O     161    43.0  83.0
# 9     10   Cu       今井加奈  16.0     3月3日   魚座         O     153    41.0  81.0
# 10    11   Cu       井村雪菜  17.0    8月27日  乙女座        AB     163    48.0  85.0
# ...

# %%
df.isnull()
# Out:
#         ID   type   name    age  birthday     星座  bloodtype  height  weight  \
# 0    False  False  False  False     False  False      False   False   False
# 1    False  False  False  False     False  False      False   False   False
# 2    False  False  False  False     False  False      False   False   False
# 3    False  False  False  False     False  False      False   False   False
# 4    False  False  False  False     False  False      False   False   False
# 5    False  False  False  False     False  False      False   False   False
# 6    False  False  False  False     False  False      False   False   False
# 7    False  False  False  False     False  False      False   False   False
# 8    False  False  False  False     False  False      False   False   False
# 9    False  False  False  False     False  False      False   False   False
# 10   False  False  False  False     False  False      False   False   False
# ...

# %%
df2 = df.dropna()
df2
# Out:
#       ID type       name   age birthday   星座 bloodtype  height  weight     B  \
# 0      1   Cu       相原雪乃  22.0    2月14日  水瓶座         A     160    51.0  92.0
# 1      2   Cu      赤西瑛梨華  16.0     7月7日   蟹座         O     154    55.0  92.0
# 2      3   Cu       浅野風香  16.0    2月11日  水瓶座         A     160    48.0  88.0
# 3      4   Cu       安部菜々  17.0    5月15日  牡牛座         O     146    40.0  84.0
# 4      5   Cu       有浦柑奈  19.0     3月6日   魚座         O     155    44.0  78.0
# 5      6   Cu        安斎都  16.0     1月6日  山羊座         B     156    41.0  78.0
# 6      7   Cu      五十嵐響子  15.0    8月10日  獅子座        AB     154    43.0  81.0
# 7      8   Cu       池袋晶葉  14.0    6月10日  双子座         B     148    39.0  75.0
# 8      9   Cu      一ノ瀬志希  18.0    5月30日  双子座         O     161    43.0  83.0
# 9     10   Cu       今井加奈  16.0     3月3日   魚座         O     153    41.0  81.0
# 10    11   Cu       井村雪菜  17.0    8月27日  乙女座        AB     163    48.0  85.0
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#       ID type   name   age birthday         星座 bloodtype  height  weight  \
# 14    15   Cu  大沼くるみ  13.0    3月30日        牡羊座         A     145    40.0
# 49    50   Cu    双葉杏  17.0     9月2日  花も恥じらう乙女座         B     139    30.0
# 151  152   Pa    佐藤心  26.0    7月22日         蟹座        AB     166     NaN
# 186  187   Pa  夢見りあむ  19.0    9月12日        乙女座        AB     149     NaN
# 190  191   --  千川ちひろ   NaN   11月28日        射手座         A     154     NaN
#
#         B     W     H hand   place
# 14    NaN   NaN   NaN    右      石川
# 49    NaN   NaN   NaN    右     北海道
# 151   NaN   NaN   NaN    右      長野
# 186   NaN   NaN   NaN    右  やさしい世界
# 190  82.0  58.0  84.0    右      東京

# %%
from matplotlib  import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
type = df['type']
labels = ['Cu', 'Co', 'Pa', '--']
sns.countplot(x='type', data = df)

# %%
sns.countplot(x='星座', data = df)

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\takah\\.matplotlib\\matplotlibrc'

# %%
import matplotlib as mpl
mpl.get_configdir()
# Out:
# 'C:\\Users\\takah\\.matplotlib'

# %%
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = 'IPAPGothic'

# %%
from matplotlib import pyplot as plt
plt.rcParams['font.family'] = 'IPAexGothic'

# %%
fc-list | grep IPAexGothic
# Out:
#   File "<ipython-input-34-c7c0b443455f>", line 1
#     fc-list | grep IPAexGothic
#                              ^
# SyntaxError: invalid syntax

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\takah\\.matplotlib\\matplotlibrc'

# %%
matplotlib.get_configdir()
# Out:
# 'C:\\Users\\takah\\.matplotlib'

# %%
sns.countplot(x='bloodtype', data = df)

# %%
bloodA = df.query('bloodtype == "A"')
bloodB = df.query('bloodtype == "B"')
bloodO = df.query('bloodtype == "O"')
bloodAB = df.query('bloodtype == "AB"')
print(len(bloodA),len(bloodB),len(bloodO),len(bloodAB))
# Out:
# 51 50 57 37

# %%
x = np.array([len(bloodA), len(bloodB), len(bloodO), len(bloodAB)])
x.sort()
x
# Out:
# array([37, 50, 51, 57])

# %%
labels = ['AB', 'B', 'O', 'A']
#x = np.array([len(bloodA), len(bloodB), len(bloodO), len(bloodAB)])
#x.sort()
fig, axes = plt.subplots(figsize=(4,4))
axes.pie(x, labels=labels, autopct="%1.1f%%", startangle = 90)

plt.show()

# %%
dfa = pd.read_csv('C:/Users/takah/OneDrive/ドキュメント/R/vector/shidouhou.csv', encoding="shift-jis")

# %%
dfa
# Out:
#     No name gender  math  static  phy  sta1  sta2 teach
# 0    1    A      m     0       1   13     6    10     C
# 1    2    B      m     0       1   14    10    13     B
# 2    3    C      m     1       1    7     6     8     B
# 3    4    D      m     1       1   12    10    15     A
# 4    5    E      m     0       0   10     5     8     B
# 5    6    F      m     0       0    6     3     6     C
# 6    7    G      m     0       0    8     5     9     A
# 7    8    H      m     0       0   15     9    10     D
# 8    9    I      m     0       0    4     3     7     D
# 9   10    J      m     1       0   14     3     3     D
# 10  11    K      f     1       1    9    11    18     A
# 11  12    L      f     0       1    6     6    14     A
# 12  13    M      f     1       1   10    11    18     A
# 13  14    N      f     0       0   12     9    11     C
# 14  15    O      f     0       1    5     7    12     B
# 15  16    P      f     1       0   12     5     5     D
# ...
